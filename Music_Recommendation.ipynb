# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/clg datasets/Spotify Million Song Dataset_exported.csv")

# %%
df
# Out:
#              artist                   song  \
# 0              ABBA  Ahe's My Kind Of Girl
# 1              ABBA       Andante, Andante
# 2              ABBA         As Good As New
# 3              ABBA                   Bang
# 4              ABBA       Bang-A-Boomerang
# ...             ...                    ...
# 57645  Ziggy Marley          Good Old Days
# 57646  Ziggy Marley          Hand To Mouth
# 57647          Zwan           Come With Me
# 57648          Zwan                 Desire
# 57649          Zwan              Heartsong
#
#                                               link  \
# 0       /a/abba/ahes+my+kind+of+girl_20598417.html
# 1            /a/abba/andante+andante_20002708.html
# 2             /a/abba/as+good+as+new_20003033.html
# 3                       /a/abba/bang_20598415.html
# 4           /a/abba/bang+a+boomerang_20002668.html
# ...                                            ...
# 57645  /z/ziggy+marley/good+old+days_10198588.html
# ...

# %%
df=df[:5001]

# %%
df.drop('link',axis=1,inplace=True)
# Out:
# <ipython-input-82-4144f711deee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('link',axis=1,inplace=True)

# %%
df
# Out:
#               artist                   song  \
# 0               ABBA  Ahe's My Kind Of Girl
# 1               ABBA       Andante, Andante
# 2               ABBA         As Good As New
# 3               ABBA                   Bang
# 4               ABBA       Bang-A-Boomerang
# ...              ...                    ...
# 4996  Elvis Costello          Love Went Mad
# 4997  Elvis Costello           Lover's Walk
# 4998  Elvis Costello             Luxembourg
# 4999  Elvis Costello       Men Called Uncle
# 5000   Elvis Presley     A Big Hunk O' Love
#
#                                                    text
# 0     Look at her face, it's a wonderful face  \nAnd...
# 1     Take it easy with me, please  \nTouch me gentl...
# 2     I'll never know why I had to go  \nWhy I had t...
# 3     Making somebody happy is a question of give an...
# 4     Making somebody happy is a question of give an...
# ...                                                 ...
# ...

# %%
df['text']=df['text'].str.replace('\n',"")
# Out:
# <ipython-input-84-dfc2f3ce0abc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text']=df['text'].str.replace('\n',"")

# %%
df.head()
# Out:
#   artist                   song  \
# 0   ABBA  Ahe's My Kind Of Girl
# 1   ABBA       Andante, Andante
# 2   ABBA         As Good As New
# 3   ABBA                   Bang
# 4   ABBA       Bang-A-Boomerang
#
#                                                 text
# 0  Look at her face, it's a wonderful face  And i...
# 1  Take it easy with me, please  Touch me gently ...
# 2  I'll never know why I had to go  Why I had to ...
# 3  Making somebody happy is a question of give an...
# 4  Making somebody happy is a question of give an...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   artist  5001 non-null   object
#  1   song    5001 non-null   object
#  2   text    5001 non-null   object
# dtypes: object(3)
# memory usage: 117.3+ KB

# %%
df.isnull().sum()
# Out:
# artist    0
# song      0
# text      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import nltk

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['num_character']=df['text'].apply(len)
# Out:
# <ipython-input-91-c48f0da8f09b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_character']=df['text'].apply(len)

# %%
df.head()
# Out:
#   artist                   song  \
# 0   ABBA  Ahe's My Kind Of Girl
# 1   ABBA       Andante, Andante
# 2   ABBA         As Good As New
# 3   ABBA                   Bang
# 4   ABBA       Bang-A-Boomerang
#
#                                                 text  num_character
# 0  Look at her face, it's a wonderful face  And i...            741
# 1  Take it easy with me, please  Touch me gently ...           1381
# 2  I'll never know why I had to go  Why I had to ...           1438
# 3  Making somebody happy is a question of give an...           1207
# 4  Making somebody happy is a question of give an...           1223

# %%
df['num_words']=df['text'].apply(lambda x:len(nltk.word_tokenize(x)))
# Out:
# <ipython-input-93-63c504269349>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_words']=df['text'].apply(lambda x:len(nltk.word_tokenize(x)))

# %%
df.head()
# Out:
#   artist                   song  \
# 0   ABBA  Ahe's My Kind Of Girl
# 1   ABBA       Andante, Andante
# 2   ABBA         As Good As New
# 3   ABBA                   Bang
# 4   ABBA       Bang-A-Boomerang
#
#                                                 text  num_character  num_words
# 0  Look at her face, it's a wonderful face  And i...            741        173
# 1  Take it easy with me, please  Touch me gently ...           1381        308
# 2  I'll never know why I had to go  Why I had to ...           1438        342
# 3  Making somebody happy is a question of give an...           1207        222
# 4  Making somebody happy is a question of give an...           1223        220

# %%
df['num_sentences']=df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))
# Out:
# <ipython-input-95-756a7156c0d1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['num_sentences']=df['text'].apply(lambda x:len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#   artist                   song  \
# 0   ABBA  Ahe's My Kind Of Girl
# 1   ABBA       Andante, Andante
# 2   ABBA         As Good As New
# 3   ABBA                   Bang
# 4   ABBA       Bang-A-Boomerang
#
#                                                 text  num_character  \
# 0  Look at her face, it's a wonderful face  And i...            741
# 1  Take it easy with me, please  Touch me gently ...           1381
# 2  I'll never know why I had to go  Why I had to ...           1438
# 3  Making somebody happy is a question of give an...           1207
# 4  Making somebody happy is a question of give an...           1223
#
#    num_words  num_sentences
# 0        173              5
# 1        308              1
# 2        342              1
# 3        222              1
# 4        220              1

# %%
df['num_sentences'][16]
# Out:
# 4

# %%
df['text'][16]
# Out:
# "They came flying from far away, now I'm under their spell  I love hearing the stories that they tell  They've seen places beyond my land and they've found new horizons  They speak strangely but I understand    And I dream I'm an eagle  And I dream I can spread my wings  Flying high, high, I'm a bird in the sky  I'm an eagle that rides on the breeze  High, high, what a feeling to fly  Over mountains and forests and seas  And to go anywhere that I please    As all good friends we talk all night, and we fly wing to wing  I have questions and they know everything  There's no limit to what I feel, we climb higher and higher  Am I dreaming or is it all real?    Is it true I'm an eagle?  Is it true I can spread my wings?  Flying high, high, I'm a bird in the sky (I'm an eagle)  I'm an eagle that rides on the breeze  High, high, what a feeling to fly (What a feeling)  Over mountains and forests and seas  And to go anywhere that I please"

# %%
df['text'][df['num_sentences']>1]
# Out:
# 0       Look at her face, it's a wonderful face  And i...
# 10      Oh, my love it makes me sad.  Why did things t...
# 13      You're so hot, teasing me  So you're blue but ...
# 16      They came flying from far away, now I'm under ...
# 18      Can you hear the drums Fernando?  I remember l...
#                               ...
# 4987    Shall I wear a buttonhole to jog your memory? ...
# 4988    You left the motor running  But I know you're ...
# 4990    In Chocolate Town all the trains are painted b...
# 4995    You won't take my love for tender  You can put...
# 4996    I've looked at it every way I can  From under ...
# Name: text, Length: 2003, dtype: object

# %%
df.describe()
# Out:
#        num_character    num_words  num_sentences
# count    5001.000000  5001.000000    5001.000000
# mean     1087.436713   239.965207       3.716657
# std       476.942310   111.138251       6.286040
# min       375.000000    62.000000       1.000000
# 25%       751.000000   162.000000       1.000000
# 50%       991.000000   217.000000       1.000000
# 75%      1323.000000   291.000000       3.000000
# max      3880.000000   980.000000      93.000000

# %% [markdown]
# LOWERING THE TEXT
#
# REMOVING SPECIAL CHARACTERS
#
# REMOVING MAKING WORDS AND PUNCTUATIONS
#
# STEMMING THE TEXT

# %%
from nltk.corpus import stopwords
import string
from nltk.stem.porter import PorterStemmer

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
ps=PorterStemmer()

# %%
def transform_text(text):
  text=text.lower()
  text=nltk.word_tokenize(text)

  y=[]
  for i in text:
    if i.isalnum():
      y.append(i)

  text=y[:]
  y.clear()

  for i in text:
    if i not in stopwords.words('english') and i not in string.punctuation:
      y.append(i)

  text=y[:]
  y.clear()

  for i in text:
    y.append(ps.stem(i))


  return " ".join(y)

# %%
df.head()
# Out:
#   artist                   song  \
# 0   ABBA  Ahe's My Kind Of Girl
# 1   ABBA       Andante, Andante
# 2   ABBA         As Good As New
# 3   ABBA                   Bang
# 4   ABBA       Bang-A-Boomerang
#
#                                                 text  num_character  \
# 0  Look at her face, it's a wonderful face  And i...            741
# 1  Take it easy with me, please  Touch me gently ...           1381
# 2  I'll never know why I had to go  Why I had to ...           1438
# 3  Making somebody happy is a question of give an...           1207
# 4  Making somebody happy is a question of give an...           1223
#
#    num_words  num_sentences
# 0        173              5
# 1        308              1
# 2        342              1
# 3        222              1
# 4        220              1

# %%
df['transformed_text']=df['text'].apply(transform_text)
# Out:
# <ipython-input-106-98fa9b97913c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['transformed_text']=df['text'].apply(transform_text)

# %%
df.head()
# Out:
#   artist                   song  \
# 0   ABBA  Ahe's My Kind Of Girl
# 1   ABBA       Andante, Andante
# 2   ABBA         As Good As New
# 3   ABBA                   Bang
# 4   ABBA       Bang-A-Boomerang
#
#                                                 text  num_character  \
# 0  Look at her face, it's a wonderful face  And i...            741
# 1  Take it easy with me, please  Touch me gently ...           1381
# 2  I'll never know why I had to go  Why I had to ...           1438
# 3  Making somebody happy is a question of give an...           1207
# 4  Making somebody happy is a question of give an...           1223
#
#    num_words  num_sentences                                   transformed_text
# 0        173              5  look face wonder face mean someth special look...
# 1        308              1  take easi pleas touch gentli like summer even ...
# 2        342              1  never know go put lousi rotten show boy tough ...
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfidf=TfidfVectorizer(analyzer='word',stop_words='english')

# %%
X=df['transformed_text']

# %%
x_transform=tfidf.fit_transform(X)

# %%
np.unique(df['transformed_text']).sum()
# Out:
# '15 go 20 met soul man quit lover ofth card dice whore ladi made love andh made babi could tell damn good stori give good advis got ta learn ta pick em son learn ta lick em son learn stickem son thigh got tri beat em much tri notto teach em much tri feed em much bull shit lie sat pour whiski mix water apictur daughter would say would sigh would drink andlaugh littl pick old fiddl ol riddl never didknow got ta learn ta pick em son learn ta lick em son learn stickem son thigh got tri beat em much tri notto teach em much tri feed em much bull shit lie year seen burri daughter marri sure herais right taught ta fuck ask told hersh said never skold would alway hold never told hermuch well told men plain simpl told love like apimpl squeez juic goe away taught tahold tighter taught let men fight wasthi poem taught dyin day got learn ta suck em daughter learn ta fuck em daughter learnhow ta take money learn ta cri got tri hold em toomuch tri scold em much tri feed em much bull shit andli got 
# ...

# %%
x_transform
# Out:
# <5001x15139 sparse matrix of type '<class 'numpy.float64'>'
# 	with 239563 stored elements in Compressed Sparse Row format>

# %%
similar=cosine_similarity(x_transform)

# %%
similar[0]
# Out:
# array([1.        , 0.03481291, 0.02411568, ..., 0.05956058, 0.12400913,
#        0.01002961])

# %%
def recommender(song_name):
  idx=df[df['song']==song_name].index[0]
  distance=sorted(list(enumerate(similar[idx])),reverse=True,key=lambda x:x[1])
  song=[]

  for s_name in distance[1:5]:
    song.append(df.iloc[s_name[0]].song)
  return song

# %%
recommender("Andante, Andante")
# Out:
# ['Make It With You', 'Love Music', 'Gonna Sing You My Lovesong', 'I Like You']

# %%
import pickle

# %%
pickle.dump(similar,open("Similar",'wb'))

# %%
df
# Out:
#               artist                   song  \
# 0               ABBA  Ahe's My Kind Of Girl
# 1               ABBA       Andante, Andante
# 2               ABBA         As Good As New
# 3               ABBA                   Bang
# 4               ABBA       Bang-A-Boomerang
# ...              ...                    ...
# 4996  Elvis Costello          Love Went Mad
# 4997  Elvis Costello           Lover's Walk
# 4998  Elvis Costello             Luxembourg
# 4999  Elvis Costello       Men Called Uncle
# 5000   Elvis Presley     A Big Hunk O' Love
#
#                                                    text  num_character  \
# 0     Look at her face, it's a wonderful face  And i...            741
# 1     Take it easy with me, please  Touch me gently ...           1381
# 2     I'll never know why I had to go  Why I had to ...           1438
# 3     Making somebody happy is a question of give an...           1207
# 4     Making somebody happy is a question of give an...           1223
# ...

# %%
pickle.dump(df,open("df",'wb'))

# %%
similar.shape
# Out:
# (5001, 5001)
